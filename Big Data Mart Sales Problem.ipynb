# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
import scipy as stats
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3873

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].mean())
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df["Item_Outlet_Sales"].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
df.loc[df['Item_Outlet_Sales']==" "]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (8523, 12)

# %%
df_cc=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        df_cc.append(i)
print(df_cc)
# Out:
# ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
len(df_cc)
# Out:
# 7

# %%
df_nc=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        df_nc.append(i)
print(df_nc)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']

# %%
len(df_nc)
# Out:
# 5

# %%
len(df.dtypes.index)==len(df_nc)+len(df_cc)
# Out:
# True

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x="Item_Fat_Content",data=df)
print(df["Item_Fat_Content"].value_counts())
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x="Outlet_Identifier",data=df)
print(df["Outlet_Identifier"].value_counts())
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x="Outlet_Size",data=df)
print(df["Outlet_Size"].value_counts())
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x="Outlet_Location_Type",data=df)
print(df["Outlet_Location_Type"].value_counts())
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x="Outlet_Type",data=df)
print(df["Outlet_Type"].value_counts())
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Item_MRP',y='Item_Outlet_Sales',hue="Item_MRP",data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Item_Visibility',y='Item_Outlet_Sales',hue="Item_MRP",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Size',y='Item_Outlet_Sales',hue='Item_MRP',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_Weight',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(18,12))
sns.pairplot(df)

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
plt.figure(figsize=(25,22))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="Set1")
plt.yticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, 'Item_Weight'),
#   Text(0, 1.5, 'Item_Visibility'),
#   Text(0, 2.5, 'Item_MRP'),
#   Text(0, 3.5, 'Outlet_Establishment_Year'),
#   Text(0, 4.5, 'Item_Outlet_Sales')])

# %%
plt.figure(figsize=(20,16))
df.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('target',fontsize=15)
plt.title('correlation between label and feature using bar plot',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,15),facecolor='white')
plotnumber=1
for column in df_nc:
    if plotnumber<=5:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column],color="orange")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
f = df[['Item_Visibility', 'Item_Outlet_Sales']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(f))
z
# Out:
#       Item_Visibility  Item_Outlet_Sales
# 0            0.970732           0.910601
# 1            0.908111           1.018440
# 2            0.956917           0.049238
# 3            1.281758           0.849103
# 4            1.281758           0.695373
# ...               ...                ...
# 8518         0.181193           0.349915
# 8519         0.371154           0.956402
# 8520         0.599784           0.579100
# 8521         1.532880           0.196725
# 8522         0.411936           0.829594
#
# [8523 rows x 2 columns]

# %%
df1 = df[(z<3).all(axis=1)] 
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df1.shape
# Out:
# (8338, 12)

# %%
Data_loss=((8523-8338)/8523)*100
Data_loss
# Out:
# 2.170597207556025

# %%
df_cc
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
df_cc = ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1[df_cc]= df1[df_cc].apply(le.fit_transform)
df1[df_cc]
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0                 156                 1          4                  9
# 1                   8                 2         14                  3
# 2                 662                 1         10                  9
# 3                1121                 2          6                  0
# 4                1297                 1          9                  1
# ...               ...               ...        ...                ...
# 8518              370                 1         13                  1
# 8519              897                 2          0                  7
# 8520             1357                 1          8                  6
# 8521              681                 2         13                  3
# 8522               50                 1         14                  8
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# ...

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber = 1

for column in df_nc:
    if plotnumber<=5:
        ax = plt.subplot(2,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize = 15)
    
    plotnumber+=1
plt.tight_layout()

# %%
df1.skew()
# Out:
# Item_Identifier             -0.007837
# Item_Weight                  0.089291
# Item_Fat_Content             1.008251
# Item_Visibility              0.794272
# Item_Type                    0.098295
# Item_MRP                     0.138990
# Outlet_Identifier           -0.065135
# Outlet_Establishment_Year   -0.423379
# Outlet_Size                 -0.087933
# Outlet_Location_Type        -0.202674
# Outlet_Type                  0.956727
# Item_Outlet_Sales            0.878267
# dtype: float64

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Item_Fat_Content             1.008251
# Outlet_Type                  0.956727
# Item_Outlet_Sales            0.878267
# Item_Visibility              0.794272
# Item_MRP                     0.138990
# Item_Type                    0.098295
# Item_Weight                  0.089291
# Item_Identifier             -0.007837
# Outlet_Identifier           -0.065135
# Outlet_Size                 -0.087933
# Outlet_Location_Type        -0.202674
# Outlet_Establishment_Year   -0.423379
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_nc_scaler = power_transform(df1)

# %%
df_nc_scaler
# Out:
# array([[-1.45970155, -0.81707423, -0.51978413, ..., -1.37581641,
#         -0.13467763,  1.03353966],
#        [-2.09372018, -1.72477171,  1.01106595, ...,  1.09508924,
#          1.05688633, -1.24784536],
#        [-0.15407347,  1.07938519, -0.51978413, ..., -1.37581641,
#         -0.13467763,  0.2216398 ],
#        ...,
#        [ 1.20238359, -0.49268289, -0.51978413, ..., -0.12639076,
#         -0.13467763, -0.41546006],
#        [-0.11269957, -1.36554488,  1.01106595, ...,  1.09508924,
#          1.05688633,  0.0649116 ],
#        [-1.86156141,  0.48935138, -0.51978413, ..., -1.37581641,
#         -0.13467763, -0.82786236]])

# %%
pd.DataFrame(df_nc_scaler, columns = df1.columns).skew().sort_values(ascending=False)
# Out:
# Item_Visibility              0.115911
# Item_Fat_Content             0.031908
# Outlet_Type                  0.010691
# Outlet_Size                 -0.043996
# Item_Weight                 -0.069766
# Item_Outlet_Sales           -0.094482
# Item_MRP                    -0.112576
# Item_Type                   -0.165742
# Outlet_Identifier           -0.214995
# Outlet_Location_Type        -0.216731
# Outlet_Establishment_Year   -0.224452
# Item_Identifier             -0.293569
# dtype: float64

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Item_Fat_Content             1.008251
# Outlet_Type                  0.956727
# Item_Outlet_Sales            0.878267
# Item_Visibility              0.794272
# Item_MRP                     0.138990
# Item_Type                    0.098295
# Item_Weight                  0.089291
# Item_Identifier             -0.007837
# Outlet_Identifier           -0.065135
# Outlet_Size                 -0.087933
# Outlet_Location_Type        -0.202674
# Outlet_Establishment_Year   -0.423379
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
df1[df_nc] = scaler.fit_transform(df1[df_nc].values)
df1[df_nc].head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    -0.817074        -1.141715  1.640811                   0.029416
# 1    -1.724772        -1.032542 -1.591460                   1.449643
# 2     1.079385        -1.117360  0.097475                   0.029416
# 3     1.437749        -1.733193  0.707513                  -0.095546
# 4    -0.911576        -1.733193 -1.471032                  -1.296374
#
#    Item_Outlet_Sales
# 0           1.033540
# 1          -1.247845
# 2           0.221640
# 3          -0.865440
# 4          -0.593111

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Item_Fat_Content             1.008251
# Outlet_Type                  0.956727
# Item_Visibility              0.115911
# Item_Type                    0.098295
# Item_Identifier             -0.007837
# Outlet_Identifier           -0.065135
# Item_Weight                 -0.069766
# Outlet_Size                 -0.087933
# Item_Outlet_Sales           -0.094482
# Item_MRP                    -0.112576
# Outlet_Location_Type        -0.202674
# Outlet_Establishment_Year   -0.224452
# dtype: float64

# %%
df1[['Item_Fat_Content', 'Outlet_Type']] = np.log1p(df1[['Item_Fat_Content', 'Outlet_Type']])

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Item_Visibility              0.115911
# Item_Type                    0.098295
# Item_Identifier             -0.007837
# Outlet_Identifier           -0.065135
# Item_Weight                 -0.069766
# Outlet_Size                 -0.087933
# Item_Outlet_Sales           -0.094482
# Item_MRP                    -0.112576
# Outlet_Location_Type        -0.202674
# Outlet_Establishment_Year   -0.224452
# Outlet_Type                 -0.238809
# Item_Fat_Content            -0.322277
# dtype: float64

# %%
df1.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.043566         -0.096515
# Item_Weight                       0.043566     1.000000         -0.015761
# Item_Fat_Content                 -0.096515    -0.015761          1.000000
# Item_Visibility                  -0.026196    -0.008224          0.041823
# Item_Type                        -0.015179     0.029998         -0.114771
# Item_MRP                          0.016750     0.022812          0.000641
# Outlet_Identifier                -0.009507    -0.010474          0.001701
# Outlet_Establishment_Year        -0.013258    -0.021669         -0.001889
# Outlet_Size                       0.001746    -0.005368         -0.011913
# Outlet_Location_Type              0.002106     0.007548         -0.007646
# Outlet_Type                      -0.008489     0.001260         -0.003094
# Item_Outlet_Sales                 0.004092     0.007907          0.010691
#
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':10},cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
corr = df1.corr()
corr
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.043566         -0.096515
# Item_Weight                       0.043566     1.000000         -0.015761
# Item_Fat_Content                 -0.096515    -0.015761          1.000000
# Item_Visibility                  -0.026196    -0.008224          0.041823
# Item_Type                        -0.015179     0.029998         -0.114771
# Item_MRP                          0.016750     0.022812          0.000641
# Outlet_Identifier                -0.009507    -0.010474          0.001701
# Outlet_Establishment_Year        -0.013258    -0.021669         -0.001889
# Outlet_Size                       0.001746    -0.005368         -0.011913
# Outlet_Location_Type              0.002106     0.007548         -0.007646
# Outlet_Type                      -0.008489     0.001260         -0.003094
# Item_Outlet_Sales                 0.004092     0.007907          0.010691
#
# ...

# %%
corr['Item_Outlet_Sales'].sort_values(ascending=False)
# Out:
# Item_Outlet_Sales            1.000000
# Item_MRP                     0.558919
# Outlet_Type                  0.502860
# Outlet_Identifier            0.219668
# Outlet_Location_Type         0.056247
# Outlet_Establishment_Year    0.041129
# Item_Type                    0.019584
# Item_Fat_Content             0.010691
# Item_Weight                  0.007907
# Item_Identifier              0.004092
# Outlet_Size                 -0.099376
# Item_Visibility             -0.102082
# Name: Item_Outlet_Sales, dtype: float64

# %%
plt.figure(figsize=(15,10))
df1.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='blue')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('correlation between target and feature using bar plot',fontsize=18)
plt.show()

# %%
df1.drop(['Item_Weight', 'Item_Identifier'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
#        'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
x = df1.drop("Item_Outlet_Sales", axis=1)
y = df1["Item_Outlet_Sales"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0            -0.491816        -1.141715  -0.766589  1.640811
# 1             1.004451        -1.032542   1.610171 -1.591460
# 2            -0.491816        -1.117360   0.659467  0.097475
# 3             1.004451        -1.733193  -0.291237  0.707513
# 4            -0.491816        -1.733193   0.421791 -1.471032
# ...                ...              ...        ...       ...
# 8333         -0.491816         0.032169   1.372495  1.165936
# 8334          1.004451        -0.213519  -1.717294 -0.449333
# 8335         -0.491816        -0.538175   0.184115 -0.856888
# 8336          1.004451         1.535557   1.372495 -0.535714
# 8337         -0.491816        -0.269024   1.610171 -1.037698
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0              1.496012                   0.029416    -0.278874
# 1             -0.615022                   1.449643    -0.278874
# ...

# %%
y
# Out:
# 0       1.033540
# 1      -1.247845
# 2       0.221640
# 3      -0.865440
# 4      -0.593111
#           ...
# 8518    0.594800
# 8519   -1.093678
# 8520   -0.415460
# 8521    0.064912
# 8522   -0.827862
# Name: Item_Outlet_Sales, Length: 8338, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#    VIF values                   Features
# 0    1.015415           Item_Fat_Content
# 1    1.027173            Item_Visibility
# 2    1.015906                  Item_Type
# 3    1.001820                   Item_MRP
# 4    4.418294          Outlet_Identifier
# 5    1.066290  Outlet_Establishment_Year
# 6    1.715085                Outlet_Size
# 7    5.151688       Outlet_Location_Type
# 8    2.466869                Outlet_Type

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxAcc=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state=i)
    mod = KNeighborsRegressor()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print("Maximum r2 score is ",maxAcc," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.6501326110245873  on Random_state  59

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=59)

# %%
x_train
# Out:
#       Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 7780         -0.491816         0.418731  -1.717294  1.687556
# 2738         -0.491816         1.879941  -0.291237 -1.431667
# 5052         -0.491816         1.629733   1.372495  1.350479
# 139          -0.491816        -0.764631   0.421791  0.642531
# 991           1.004451        -0.768927  -1.004266  0.520905
# ...                ...              ...        ...       ...
# 3893         -3.049701        -1.733193  -0.291237  1.198935
# 6351          2.889525        -0.219270  -0.291237  0.542594
# 663           1.004451         2.130142  -0.291237  0.650839
# 7596          1.004451         0.535287  -0.291237 -0.553063
# 4273         -0.491816        -1.211779   1.610171 -0.133139
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 7780          -0.966861                   1.139069    -0.278874
# 2738          -0.263183                  -1.483886     1.383207
# ...

# %%
x_test
# Out:
#       Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 5020         -0.491816         0.977663  -0.528913 -0.227265
# 202           1.004451        -0.094092   1.372495 -0.462915
# 5237         -0.491816         0.072776   1.372495 -1.668899
# 575           1.004451        -0.115698  -1.004266  0.261725
# 4231          1.004451         0.081059  -0.291237  0.533746
# ...                ...              ...        ...       ...
# 2710          1.004451        -0.280903   0.659467 -0.539772
# 2020          1.004451        -0.087440  -1.717294 -0.986499
# 4575          1.004451         0.286143  -0.766589 -1.339993
# 1435         -0.491816        -0.821804  -0.291237  0.484730
# 7127         -0.491816        -1.733193  -0.766589 -1.340046
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 5020          -1.318700                  -1.296374    -1.940955
# 202           -0.263183                  -1.483886     1.383207
# ...

# %%
y_train
# Out:
# 7956    2.088966
# 2800   -1.824715
# 5160   -1.225254
# 143     0.542883
# 1016    1.721792
#           ...
# 3979    1.993538
# 6486   -0.015268
# 680    -1.781661
# 7767   -0.002712
# 4365   -0.333966
# Name: Item_Outlet_Sales, Length: 6670, dtype: float64

# %%
y_test
# Out:
# 5127    0.422986
# 208    -1.464181
# 5350   -0.927814
# 591     0.994658
# 4321   -1.800088
#           ...
# 2771   -0.065422
# 2066   -0.237817
# 4671   -0.101350
# 1469    0.637341
# 7286   -0.494083
# Name: Item_Outlet_Sales, Length: 1668, dtype: float64

# %%
print("x_train shape =",x_train.shape)
print("x_test shape =",x_test.shape)
print("y_train shape =",y_train.shape)
print("y_test shape =",y_test.shape)
# Out:
# x_train shape = (6670, 9)
# x_test shape = (1668, 9)
# y_train shape = (6670,)
# y_test shape = (1668,)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
rfrpred=rfr.predict(x_test)
print('R2_Score:',r2_score(y_test,rfrpred))
print('MAE:',mean_absolute_error(y_test, rfrpred))
print('MSE:',mean_squared_error(y_test, rfrpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, rfrpred)))
print("Cross_Validaton_Score",cross_val_score(rfr,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6564928575425666
# MAE: 0.46856575875757683
# MSE: 0.3585974422624641
# RMSE: 0.5988300612548305
# Cross_Validaton_Score 0.6370529270723475

# %%
svr = SVR()
svr.fit(x_train,y_train)
svrpred=svr.predict(x_test)
print('R2_Score:',r2_score(y_test,svrpred))
print('MAE:',mean_absolute_error(y_test, svrpred))
print('MSE:',mean_squared_error(y_test, svrpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, svrpred)))
print("Cross_Validaton_Score",cross_val_score(svr,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6919552048538739
# MAE: 0.44012911149163786
# MSE: 0.3215772308296442
# RMSE: 0.5670777996268627
# Cross_Validaton_Score 0.6717725022499166

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
lrpred=lr.predict(x_test)
print('R2_score:',r2_score(y_test,lrpred))
print('MAE:',mean_absolute_error(y_test, lrpred))
print('MSE:',mean_squared_error(y_test, lrpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, lrpred)))
print("Cross_Validaton_Score",cross_val_score(lr,x,y,cv=5).mean())
# Out:
# R2_score: 0.6227613057213179
# MAE: 0.5000198075523928
# MSE: 0.3938108242029645
# RMSE: 0.6275434839140348
# Cross_Validaton_Score 0.6072022572271552

# %%
sgd = SGDRegressor()
sgd.fit(x_train,y_train)
sgdpred=sgd.predict(x_test)
print('R2_Score:',r2_score(y_test,sgdpred))
print('MAE:',mean_absolute_error(y_test, sgdpred))
print('MSE:',mean_squared_error(y_test, sgdpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, sgdpred)))
print("Cross_Validaton_Score",cross_val_score(sgd,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6212942622208746
# MAE: 0.5008055339489346
# MSE: 0.39534231505693407
# RMSE: 0.6287625267594548
# Cross_Validaton_Score 0.6055239884622928

# %%
knn = KNeighborsRegressor()
knn.fit(x_train,y_train)
knnpred=knn.predict(x_test)
print('R2_Score:',r2_score(y_test,knnpred))
print('MAE:',mean_absolute_error(y_test, knnpred))
print('MSE:',mean_squared_error(y_test, knnpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, knnpred)))
print("Cross_Validaton_Score",cross_val_score(knn,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6501326110245873
# MAE: 0.4705969606647923
# MSE: 0.36523709498464507
# RMSE: 0.6043484880304121
# Cross_Validaton_Score 0.6087195406359927

# %%
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
gbpred=gb.predict(x_test)
print('R2_Score:',r2_score(y_test,gbpred))
print('MAE:',mean_absolute_error(y_test, gbpred))
print('MSE:',mean_squared_error(y_test, gbpred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, gbpred)))
print("Cross_Validaton_Score",cross_val_score(gb,x,y,cv=5).mean())
# Out:
# R2_Score: 0.692755282457107
# MAE: 0.4404579394620289
# MSE: 0.32074200574501155
# RMSE: 0.566340891817827
# Cross_Validaton_Score 0.6769363189700732

# %%
from sklearn.model_selection import GridSearchCV
parameters={'loss' : ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'max_features' : ['auto', 'sqrt', 'log2'],
           'learning_rate':[0.1,.2,.4,.5],
           'criterion' : ['friedman_mse', 'squared_error', 'mse'], 
}
GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error', 'mse'],
#                          'learning_rate': [0.1, 0.2, 0.4, 0.5],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'loss': 'huber',
#  'max_features': 'sqrt'}

# %%
GCV.best_estimator_
# Out:
# GradientBoostingRegressor(loss='huber', max_features='sqrt')

# %%
gcvpred1=GCV.best_estimator_.predict(x_test)
GCV.best_estimator_.score(x_train,y_train)
# Out:
# 0.6941589738767676

# %%
final_model=GradientBoostingRegressor(max_depth=4)

# %%
final_model.fit(x_test,y_test)
pred=final_model.predict(x_test)
final_model.fit(x_train,y_train)
pred1=final_model.predict(x_train)

# %%
print("Test Accuracy=",final_model.score(x_test,y_test))
print("Train Accuracy=",final_model.score(x_train,y_train))
# Out:
# Test Accuracy= 0.6909664683117132
# Train Accuracy= 0.7162982900725666

# %%
import joblib
joblib.dump(final_model,"Big Data Mart Sales Problem.pkl")
# Out:
# ['Big Data Mart Sales Problem.pkl']

# %%
model=joblib.load("Big Data Mart Sales Problem.pkl")
Prediction = model.predict(x_test)
Prediction
# Out:
# array([ 0.13187769, -1.53282158, -0.92612069, ..., -0.63706656,
#         0.43484071, -0.71770013])

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, Prediction, c='crimson')
plt1 = max(max(Prediction), max(y_test))
plt2 = min(min(Prediction), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.title("Gradient Boosting Regressor")
plt.xlabel('Actual price', fontsize=15)
plt.ylabel('Predicted price', fontsize=15)
plt.show()

# %% [markdown]
# # Test Data

# %%
dff = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Test.csv")

# %%
dff
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
dff.shape
# Out:
# (5681, 11)

# %%
dff.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
dff.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
dff.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
dff.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
dff.isnull().sum().sum()
# Out:
# 2582

# %%
dff.nunique()
# Out:
# Item_Identifier              1543
# Item_Weight                   410
# Item_Fat_Content                5
# Item_Visibility              5277
# Item_Type                      16
# Item_MRP                     4402
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# dtype: int64

# %%
dff.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
dff.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
dff['Item_Weight'] = dff['Item_Weight'].fillna(dff['Item_Weight'].mean())
dff['Outlet_Size'] = dff['Outlet_Size'].fillna(dff['Outlet_Size'].mode()[0])

# %%
dff.isnull().sum().sum()
# Out:
# 0

# %%
dff.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  5681.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.245189         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       9.195000         0.027047    94.412000                1987.000000
# 50%      12.695633         0.054154   141.415400                1999.000000
# 75%      15.850000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
dff.shape
# Out:
# (5681, 11)

# %%
dff_nc=[]
for i in dff.dtypes.index:
    if dff.dtypes[i]!='object':
        dff_nc.append(i)
print(dff_nc)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']

# %%
dff_cc=[]
for i in dff.dtypes.index:
    if dff.dtypes[i]=='object':
        dff_cc.append(i)
print(dff_cc)
# Out:
# ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
len(dff_cc)
# Out:
# 7

# %%
len(dff_nc)
# Out:
# 4

# %%
len(dff.dtypes.index)==len(dff_nc)+len(dff_cc)
# Out:
# True

# %%
plt.figure(figsize=(20,15),facecolor='white')
plotnumber=1
for column in dff_nc:
    if plotnumber<=5:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(dff[column],color="orange")
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
z=np.abs(zscore(dff[["Item_Visibility"]]))
df2=dff[(z<3).all(axis=1)]
df2.shape
# Out:
# (5600, 11)

# %%
dff.shape
# Out:
# (5681, 11)

# %%
Data_loss=((5681-5600)/5681)*100
Data_loss
# Out:
# 1.425805315965499

# %%
df2.skew()
# Out:
# Item_Weight                  0.140901
# Item_Visibility              0.787861
# Item_MRP                     0.133061
# Outlet_Establishment_Year   -0.411451
# dtype: float64

# %%
df2.skew().sort_values(ascending=False)
# Out:
# Item_Visibility              0.787861
# Item_Weight                  0.140901
# Item_MRP                     0.133061
# Outlet_Establishment_Year   -0.411451
# dtype: float64

# %%
scaler = PowerTransformer(method='yeo-johnson')
df2[['Item_Visibility']] = scaler.fit_transform(df2[['Item_Visibility']].values)

# %%
df2.skew().sort_values(ascending=False)
# Out:
# Item_Weight                  0.140901
# Item_MRP                     0.133061
# Item_Visibility              0.105676
# Outlet_Establishment_Year   -0.411451
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2[dff_cc]= df2[dff_cc].apply(le.fit_transform)
df2[dff_cc]
# Out:
#       Item_Identifier  Item_Fat_Content  Item_Type  Outlet_Identifier  \
# 0                1102                 1         13                  9
# 1                1066                 4          4                  2
# 2                1405                 1         11                  0
# 3                 809                 1         13                  2
# 4                1183                 2          4                  5
# ...               ...               ...        ...                ...
# 5676              231                 2         13                  8
# 5677              306                 2         15                  3
# 5678             1411                 1          8                  7
# 5679              517                 2          3                  2
# 5680              986                 2          3                  7
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# ...

# %%
df2.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
df2.drop(['Item_Weight', 'Item_Identifier'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df2 = pd.DataFrame(sc.fit_transform(df2), columns=df2.columns)
df2.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  \
# 0         -0.574248        -1.453107   1.363909 -0.538563           1.498198
# 1          4.122617        -0.440632  -0.767463 -0.871149          -0.975450
# 2         -0.574248         0.926222   0.890271  1.629171          -1.682207
# 3         -0.574248        -1.170062   1.363909  0.225158          -0.975450
# 4          0.991374         1.229130  -0.767463  1.507359           0.084685
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                   0.128501    -0.276176             -1.377862    -0.277213
# 1                   1.085897    -0.276176             -0.142507    -0.277213
# 2                   0.008826    -0.276176              1.092848    -1.544474
# 3                   1.085897    -0.276176             -0.142507    -0.277213
# 4                  -1.546944    -0.276176              1.092848     2.257309

# %%
model = joblib.load("Big Data Mart Sales Problem.pkl")

# %%
Prediction = model.predict(df2)

# %%
predict=pd.DataFrame(prediction,columns=['Item_Outlet_Sales'])
predict
# Out:
#       Item_Outlet_Sales
# 0             -0.114218
# 1             -0.363532
# 2             -1.134800
# 3              0.331464
# 4              1.393924
# ...                 ...
# 5595           0.162143
# 5596           0.307602
# 5597          -0.037154
# 5598           1.124620
# 5599          -0.349996
#
# [5600 rows x 1 columns]
